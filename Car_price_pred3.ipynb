# %% [markdown]
# <a href="https://colab.research.google.com/github/Notharley/ETH-AVA-4/blob/main/Car_price_pred3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # DATA GATHERING

# %%
df = pd.read_csv("Car data.csv")
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe().T
# Out:
#                count          mean           std      min      25%      50%  \
# Year           301.0   2013.627907      2.891554  2003.00   2012.0   2014.0
# Selling_Price  301.0      4.661296      5.082812     0.10      0.9      3.6
# Present_Price  301.0      7.628472      8.644115     0.32      1.2      6.4
# Kms_Driven     301.0  36947.205980  38886.883882   500.00  15000.0  32000.0
# Owner          301.0      0.043189      0.247915     0.00      0.0      0.0
#
#                    75%       max
# Year            2016.0    2018.0
# Selling_Price      6.0      35.0
# Present_Price      9.9      92.6
# Kms_Driven     48767.0  500000.0
# Owner              0.0       3.0

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
import seaborn as sns
import pandas as pd

numeric_df = df.select_dtypes(include=['number'])

correlation_matrix = numeric_df.corr()

sns.heatmap(correlation_matrix, annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.Car_Name.nunique()
# Out:
# 98

# %% [markdown]
# ## Car_Name

# %%
df.Car_Name
# Out:
# 0         ritz
# 1          sx4
# 2         ciaz
# 3      wagon r
# 4        swift
#         ...
# 296       city
# 297       brio
# 298       city
# 299       city
# 300       brio
# Name: Car_Name, Length: 301, dtype: object

# %%
df.shape
# Out:
# (301, 9)

# %%
## one-hot encoding
df = pd.get_dummies(df,columns=["Car_Name"])

# %%
df.shape
# Out:
# (301, 106)

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Car_Name_800  Car_Name_Activa 3g  ...  \
# 0         Manual      0         False               False  ...
# 1         Manual      0         False               False  ...
# 2         Manual      0         False               False  ...
# 3         Manual      0         False               False  ...
# 4         Manual      0         False               False  ...
# ..           ...    ...           ...                 ...  ...
# 296       Manual      0         False               False  ...
# 297       Manual      0         False               False  ...
# 298       Manual      0         False               False  ...
# 299       Manual      0         False               False  ...
# 300       Manual      0         False               False  ...
#
#      Car_Name_land cruiser  Car_Name_omni  Car_Name_ritz  Car_Name_s cross  \
# 0                    False          False           True             False
# 1                    False          False          False             False
# 2                    False          False          False             False
# 3                    False          False          False             False
# 4                    False          False          False             False
# ..                     ...            ...            ...               ...
# 296                  False          False          False             False
# 297                  False          False          False             False
# 298                  False          False          False             False
# 299                  False          False          False             False
# 300                  False          False          False             False
#
#      Car_Name_swift  Car_Name_sx4  Car_Name_verna  Car_Name_vitara brezza  \
# 0             False         False           False                   False
# 1             False          True           False                   False
# 2             False         False           False                   False
# 3             False         False           False                   False
# 4              True         False           False                   False
# ..              ...           ...             ...                     ...
# 296           False         False           False                   False
# 297           False         False           False                   False
# 298           False         False           False                   False
# 299           False         False           False                   False
# 300           False         False           False                   False
#
#      Car_Name_wagon r  Car_Name_xcent
# 0               False           False
# 1               False           False
# 2               False           False
# 3                True           False
# 4               False           False
# ..                ...             ...
# 296             False           False
# 297             False           False
# 298             False           False
# 299             False           False
# 300             False           False
#
# [301 rows x 106 columns]

# %%
df.dtypes
# Out:
# Year                        int64
# Selling_Price             float64
# Present_Price             float64
# Kms_Driven                  int64
# Fuel_Type                  object
#                            ...
# Car_Name_sx4                 bool
# Car_Name_verna               bool
# Car_Name_vitara brezza       bool
# Car_Name_wagon r             bool
# Car_Name_xcent               bool
# Length: 106, dtype: object

# %%
## Fuel_Type
df.Fuel_Type.value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
df.Fuel_Type.value_counts().to_dict()
# Out:
# {'Petrol': 239, 'Diesel': 60, 'CNG': 2}

# %%
df["Fuel_Type"].replace({'Petrol': 1 , 'Diesel': 0 , 'CNG': 2})
# Out:
# <ipython-input-36-4e3e55f25a08>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Fuel_Type"].replace({'Petrol': 1 , 'Diesel': 0 , 'CNG': 2})
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 296    0
# 297    1
# 298    1
# 299    0
# 300    1
# Name: Fuel_Type, Length: 301, dtype: int64

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Car_Name_800  Car_Name_Activa 3g  ...  \
# 0         Manual      0         False               False  ...
# 1         Manual      0         False               False  ...
# 2         Manual      0         False               False  ...
# 3         Manual      0         False               False  ...
# 4         Manual      0         False               False  ...
# ..           ...    ...           ...                 ...  ...
# 296       Manual      0         False               False  ...
# 297       Manual      0         False               False  ...
# 298       Manual      0         False               False  ...
# 299       Manual      0         False               False  ...
# 300       Manual      0         False               False  ...
#
#      Car_Name_land cruiser  Car_Name_omni  Car_Name_ritz  Car_Name_s cross  \
# 0                    False          False           True             False
# 1                    False          False          False             False
# 2                    False          False          False             False
# 3                    False          False          False             False
# 4                    False          False          False             False
# ..                     ...            ...            ...               ...
# 296                  False          False          False             False
# 297                  False          False          False             False
# 298                  False          False          False             False
# 299                  False          False          False             False
# 300                  False          False          False             False
#
#      Car_Name_swift  Car_Name_sx4  Car_Name_verna  Car_Name_vitara brezza  \
# 0             False         False           False                   False
# 1             False          True           False                   False
# 2             False         False           False                   False
# 3             False         False           False                   False
# 4              True         False           False                   False
# ..              ...           ...             ...                     ...
# 296           False         False           False                   False
# 297           False         False           False                   False
# 298           False         False           False                   False
# 299           False         False           False                   False
# 300           False         False           False                   False
#
#      Car_Name_wagon r  Car_Name_xcent
# 0               False           False
# 1               False           False
# 2               False           False
# 3                True           False
# 4               False           False
# ..                ...             ...
# 296             False           False
# 297             False           False
# 298             False           False
# 299             False           False
# 300             False           False
#
# [301 rows x 106 columns]

# %%
df.Seller_Type.unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
df["Seller_Type"].replace({'Dealer': 1 , 'Individual': 0},inplace=True)
# Out:
# <ipython-input-41-1883c3fb88e1>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Seller_Type"].replace({'Dealer': 1 , 'Individual': 0},inplace=True)
# <ipython-input-41-1883c3fb88e1>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Seller_Type"].replace({'Dealer': 1 , 'Individual': 0},inplace=True)

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol            1
# 1    2013           4.75           9.54       43000    Diesel            1
# 2    2017           7.25           9.85        6900    Petrol            1
# 3    2011           2.85           4.15        5200    Petrol            1
# 4    2014           4.60           6.87       42450    Diesel            1
# ..    ...            ...            ...         ...       ...          ...
# 296  2016           9.50          11.60       33988    Diesel            1
# 297  2015           4.00           5.90       60000    Petrol            1
# 298  2009           3.35          11.00       87934    Petrol            1
# 299  2017          11.50          12.50        9000    Diesel            1
# 300  2016           5.30           5.90        5464    Petrol            1
#
#     Transmission  Owner  Car_Name_800  Car_Name_Activa 3g  ...  \
# 0         Manual      0         False               False  ...
# 1         Manual      0         False               False  ...
# 2         Manual      0         False               False  ...
# 3         Manual      0         False               False  ...
# 4         Manual      0         False               False  ...
# ..           ...    ...           ...                 ...  ...
# 296       Manual      0         False               False  ...
# 297       Manual      0         False               False  ...
# 298       Manual      0         False               False  ...
# 299       Manual      0         False               False  ...
# 300       Manual      0         False               False  ...
#
#      Car_Name_land cruiser  Car_Name_omni  Car_Name_ritz  Car_Name_s cross  \
# 0                    False          False           True             False
# 1                    False          False          False             False
# 2                    False          False          False             False
# 3                    False          False          False             False
# 4                    False          False          False             False
# ..                     ...            ...            ...               ...
# 296                  False          False          False             False
# 297                  False          False          False             False
# 298                  False          False          False             False
# 299                  False          False          False             False
# 300                  False          False          False             False
#
#      Car_Name_swift  Car_Name_sx4  Car_Name_verna  Car_Name_vitara brezza  \
# 0             False         False           False                   False
# 1             False          True           False                   False
# 2             False         False           False                   False
# 3             False         False           False                   False
# 4              True         False           False                   False
# ..              ...           ...             ...                     ...
# 296           False         False           False                   False
# 297           False         False           False                   False
# 298           False         False           False                   False
# 299           False         False           False                   False
# 300           False         False           False                   False
#
#      Car_Name_wagon r  Car_Name_xcent
# 0               False           False
# 1               False           False
# 2               False           False
# 3                True           False
# 4               False           False
# ..                ...             ...
# 296             False           False
# 297             False           False
# 298             False           False
# 299             False           False
# 300             False           False
#
# [301 rows x 106 columns]

# %%
df["Transmission"].value_counts().to_dict()
# Out:
# {'Manual': 261, 'Automatic': 40}

# %%
df["Transmission"].replace({'Manual': 0 , 'Automatic': 1},inplace=True)
# Out:
# <ipython-input-44-4cfb9ebc12ad>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Transmission"].replace({'Manual': 0 , 'Automatic': 1},inplace=True)
# <ipython-input-44-4cfb9ebc12ad>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Transmission"].replace({'Manual': 0 , 'Automatic': 1},inplace=True)

# %%
df.dtypes
# Out:
# Year                        int64
# Selling_Price             float64
# Present_Price             float64
# Kms_Driven                  int64
# Fuel_Type                  object
#                            ...
# Car_Name_sx4                 bool
# Car_Name_verna               bool
# Car_Name_vitara brezza       bool
# Car_Name_wagon r             bool
# Car_Name_xcent               bool
# Length: 106, dtype: object

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol            1
# 1    2013           4.75           9.54       43000    Diesel            1
# 2    2017           7.25           9.85        6900    Petrol            1
# 3    2011           2.85           4.15        5200    Petrol            1
# 4    2014           4.60           6.87       42450    Diesel            1
# ..    ...            ...            ...         ...       ...          ...
# 296  2016           9.50          11.60       33988    Diesel            1
# 297  2015           4.00           5.90       60000    Petrol            1
# 298  2009           3.35          11.00       87934    Petrol            1
# 299  2017          11.50          12.50        9000    Diesel            1
# 300  2016           5.30           5.90        5464    Petrol            1
#
#      Transmission  Owner  Car_Name_800  Car_Name_Activa 3g  ...  \
# 0               0      0         False               False  ...
# 1               0      0         False               False  ...
# 2               0      0         False               False  ...
# 3               0      0         False               False  ...
# 4               0      0         False               False  ...
# ..            ...    ...           ...                 ...  ...
# 296             0      0         False               False  ...
# 297             0      0         False               False  ...
# 298             0      0         False               False  ...
# 299             0      0         False               False  ...
# 300             0      0         False               False  ...
#
#      Car_Name_land cruiser  Car_Name_omni  Car_Name_ritz  Car_Name_s cross  \
# 0                    False          False           True             False
# 1                    False          False          False             False
# 2                    False          False          False             False
# 3                    False          False          False             False
# 4                    False          False          False             False
# ..                     ...            ...            ...               ...
# 296                  False          False          False             False
# 297                  False          False          False             False
# 298                  False          False          False             False
# 299                  False          False          False             False
# 300                  False          False          False             False
#
#      Car_Name_swift  Car_Name_sx4  Car_Name_verna  Car_Name_vitara brezza  \
# 0             False         False           False                   False
# 1             False          True           False                   False
# 2             False         False           False                   False
# 3             False         False           False                   False
# 4              True         False           False                   False
# ..              ...           ...             ...                     ...
# 296           False         False           False                   False
# 297           False         False           False                   False
# 298           False         False           False                   False
# 299           False         False           False                   False
# 300           False         False           False                   False
#
#      Car_Name_wagon r  Car_Name_xcent
# 0               False           False
# 1               False           False
# 2               False           False
# 3                True           False
# 4               False           False
# ..                ...             ...
# 296             False           False
# 297             False           False
# 298             False           False
# 299             False           False
# 300             False           False
#
# [301 rows x 106 columns]

# %%
df.columns[0:9]
# Out:
# Index(['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner', 'Car_Name_800'],
#       dtype='object')

# %%
df.Owner.value_counts()
# Out:
# Owner
# 0    290
# 1     10
# 3      1
# Name: count, dtype: int64

# %%
## Label Encoding
df['Fuel_Type'].replace({"Diesel":0, "Petrol":1, "CNG":2},inplace=True)
df.Seller_Type.replace({"Individual" : 0 ,"Dealer":1 },inplace=True)
df.Transmission.replace({"Manual":0 , "Automatic":1},inplace=True)
# Out:
# <ipython-input-49-5549b3b8c5b1>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fuel_Type'].replace({"Diesel":0, "Petrol":1, "CNG":2},inplace=True)
# <ipython-input-49-5549b3b8c5b1>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Fuel_Type'].replace({"Diesel":0, "Petrol":1, "CNG":2},inplace=True)
# <ipython-input-49-5549b3b8c5b1>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Seller_Type.replace({"Individual" : 0 ,"Dealer":1 },inplace=True)
# <ipython-input-49-5549b3b8c5b1>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Transmission.replace({"Manual":0 , "Automatic":1},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Columns: 106 entries, Year to Car_Name_xcent
# dtypes: bool(98), float64(2), int64(6)
# memory usage: 47.7 KB

# %% [markdown]
# # Feature Selection

# %%
x = df.drop("Selling_Price",axis=1)
y = df["Selling_Price"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error , mean_squared_error , r2_score

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y , test_size=0.3,random_state=6)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((210, 105), (91, 105), (210,), (91,))

# %%
car_model = LinearRegression()
car_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Model Evaluation

# %%
def car_model_evalution(model,x,y):

    y_pred = model.predict(x)

    mse = mean_squared_error(y,y_pred)
    print(f"Mean Squared Error = {mse}")

    mae = mean_absolute_error(y,y_pred)
    print(f"Mean Abosolute Error = {mae}")

    r2 = r2_score(y,y_pred)
    print(f"r2 Score = {r2}")

    return "Success"

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def car_model_evalution(model, x, y):
    """
    Evaluates a car model using various metrics.

    Args:
        model: The trained car model.
        x: The input features for evaluation.
        y: The target values for evaluation.

    Returns:
        str: "Success" if the evaluation completes successfully.
    """
    y_pred = model.predict(x)

    mse = mean_squared_error(y, y_pred)
    print(f"Mean Squared Error = {mse}")

    mae = mean_absolute_error(y, y_pred)
    print(f"Mean Abosolute Error = {mae}")

    r2 = r2_score(y, y_pred)
    print(f"r2 Score = {r2}")

    return "Success"

# %%
## Training Data Evalution

car_model_evalution(car_model,x_train,y_train)
# Out:
# Mean Squared Error = 1.339513052670365
# Mean Abosolute Error = 0.6676002225667017
# r2 Score = 0.9519579613687336
# 'Success'

# %% [raw]
# Trainig >> 95%
# testing >> 70%
#
#
# bais = 95% [low bais]
# varience = Training - Testing >> 25% [High varience]
#
# Overfitting >> Low bais and High Variance
#
# ## Model is overfitting

# %% [markdown]
# ## Ridge and Lasso HyperParameter Tuning

# %%
## Ridge and Lasso HyperParameter Tuning
from sklearn.model_selection import GridSearchCV , RandomizedSearchCV
from sklearn.linear_model import Lasso , Ridge

# %%
hyper = ({"alpha" : np.arange(0.0001 , 2, 0.01)})
lasso_model= Lasso()

# %%
gscv = GridSearchCV(lasso_model,hyper)
gscv.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.964e+01, tolerance: 4.755e-01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.111e+02, tolerance: 5.161e-01
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(estimator=Lasso(),
#              param_grid={'alpha': array([1.0000e-04, 1.0100e-02, 2.0100e-02, 3.0100e-02, 4.0100e-02,
#        5.0100e-02, 6.0100e-02, 7.0100e-02, 8.0100e-02, 9.0100e-02,
#        1.0010e-01, 1.1010e-01, 1.2010e-01, 1.3010e-01, 1.4010e-01,
#        1.5010e-01, 1.6010e-01, 1.7010e-01, 1.8010e-01, 1.9010e-01,
#        2.0010e-01, 2.1010e-01, 2.2010e-01, 2.3010e-01, 2.4010e-01,
#        2.5010e-01, 2.6010...
#        1.6501e+00, 1.6601e+00, 1.6701e+00, 1.6801e+00, 1.6901e+00,
#        1.7001e+00, 1.7101e+00, 1.7201e+00, 1.7301e+00, 1.7401e+00,
#        1.7501e+00, 1.7601e+00, 1.7701e+00, 1.7801e+00, 1.7901e+00,
#        1.8001e+00, 1.8101e+00, 1.8201e+00, 1.8301e+00, 1.8401e+00,
#        1.8501e+00, 1.8601e+00, 1.8701e+00, 1.8801e+00, 1.8901e+00,
#        1.9001e+00, 1.9101e+00, 1.9201e+00, 1.9301e+00, 1.9401e+00,
#        1.9501e+00, 1.9601e+00, 1.9701e+00, 1.9801e+00, 1.9901e+00])})

# %%
gscv.best_estimator_
# Out:
# Lasso(alpha=0.040100000000000004)

# %%
lasso_model = Lasso(alpha=0.040100000000000004)
lasso_model.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.040100000000000004)

# %%
# Training data Evaluation

car_model_evalution(lasso_model,x_train,y_train)
# Out:
# Mean Squared Error = 2.6126434058474075
# Mean Abosolute Error = 1.045666684316337
# r2 Score = 0.9062967582262653
# 'Success'

# %%
# Testing data Evaluation


car_model_evalution(lasso_model,x_test,y_test)
# Out:
# Mean Squared Error = 3.0035274105067895
# Mean Abosolute Error = 1.197505404204522
# r2 Score = 0.8557192176988698
# 'Success'

# %% [raw]
# lasso_model >> train[90]
#                test[85]
#
# Best model >low bais & low Varience

# %% [markdown]
# ## Ridge Model

# %%
ridge = Ridge()
hyper = ({"alpha" : np.arange(0.0001,2,0.1)})
gscv_ridge = GridSearchCV(ridge,hyper)
gscv_ridge.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=Ridge(),
#              param_grid={'alpha': array([1.0000e-04, 1.0010e-01, 2.0010e-01, 3.0010e-01, 4.0010e-01,
#        5.0010e-01, 6.0010e-01, 7.0010e-01, 8.0010e-01, 9.0010e-01,
#        1.0001e+00, 1.1001e+00, 1.2001e+00, 1.3001e+00, 1.4001e+00,
#        1.5001e+00, 1.6001e+00, 1.7001e+00, 1.8001e+00, 1.9001e+00])})

# %%
gscv_ridge.best_estimator_
# Out:
# Ridge(alpha=1.9001000000000001)

# %%
ridge = Ridge(alpha=1.9001000000000001)
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=1.9001000000000001)

# %%
car_model_evalution(ridge,x_train,y_train)
# Out:
# Mean Squared Error = 1.887781177342818
# Mean Abosolute Error = 0.8562873236192242
# r2 Score = 0.9322941601289498
# 'Success'

# %%
car_model_evalution(ridge,x_test,y_test)
# Out:
# Mean Squared Error = 3.286531496164477
# Mean Abosolute Error = 1.161924500106185
# r2 Score = 0.8421245187691146
# 'Success'

# %% [markdown]
# # Conclusion :

# %% [raw]
#                             Train   |    Test      |    Bais and Variance
# --------------------------------------------------------------------------------------------
# Linear Regression Model >    95%    |     70%      |     Low and High        >> Overfitting
# Lasso  Model            >    90%    |     85%      |     Low and Low         >> Best Model
# Ridge  Model            >    93%    |     84%      |     Low and Low         >> Best Model

# %% [markdown]
# ## Lasso Model is the Best Model

# %%
import pickle
# with open("Car_Pred_Model.pkl" ,"rb") as

with open("Car_Pred_Model.pkl","wb") as file:
    pickle.dump(lasso_model,file)

# %%
import json

# %%
columns = {"column_names" : df.columns.to_list()}
with open("Column.json","w") as col_file:
    json.dump(columns,col_file)

# %%
encoded_data = {
    "Fuel_Type" : {"Diesel":0, "Petrol":1, "CNG":2 },
    "Seller_Type" : {"Individual" : 0 ,"Dealer":1 },
    "Transmission" : {"Manual":0 , "Automatic":1}
}

with open("encoded_data","w") as enc_file:  # encoded_data.json
    json.dump(encoded_data,enc_file)
